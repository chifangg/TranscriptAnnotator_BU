# %%
import tiktoken
def count_tokens_in_messages(messages, model="gpt-4o-mini"):
    """Count tokens in messages using tiktoken"""
    try:
        encoding = tiktoken.encoding_for_model(model)
    except KeyError:
        encoding = tiktoken.get_encoding("cl100k_base")

    total_tokens = 0
    for message in messages:
        # Count tokens for role and content
        total_tokens += len(encoding.encode(message.get("role", "")))
        total_tokens += len(encoding.encode(message.get("content", "")))
        # Add extra tokens for message formatting (estimated)
        total_tokens += 4

    return total_tokens

model = "gpt-4o-mini"
for name, content in transcripts.items():
    encoding = tiktoken.encoding_for_model(model)
    current_tokens = len(encoding.encode(content))
    print(current_tokens)
# Out:
# 16094

# %%
import concurrent
from tqdm import tqdm
import tiktoken
import json
import requests
from collections import defaultdict

# from . import prompts
from openai import RateLimitError, APITimeoutError
import time
from pydantic import BaseModel
from typing import Dict, List
def request_gpt(
    client, messages, model="gpt-4o-mini", temperature=0.5, format=None, seed=None
):
    try:
        if format == "json":
            response = client.chat.completions.create(
                model=model,
                messages=messages,
                response_format={"type": "json_object"},
                temperature=temperature,
                seed=seed,
            )
        else:
            response = client.chat.completions.create(
                model=model, messages=messages, temperature=temperature, seed=seed
            )
        return response.choices[0].message.content
    except RateLimitError as e:
        print("RateLimitError")
        print(e)
        time.sleep(5)
        return request_gpt(client, messages, model, temperature, format)
    except APITimeoutError as e:
        print("APITimeoutError")
        print(messages)
        time.sleep(5)
        return request_gpt(client, messages, model, temperature, format)

# %%
import re

def parseTranscript(content: str):
    messages = []
    lines = content.split('\n')
    current_message = None

    for i, line in enumerate(lines):
        line = line.strip()
        
        # Check if line matches speaker pattern: [Speaker Name] hh:mm:ss
        speaker_match = re.match(r'^\[([^\]]+)\]\s+(\d{1,2}:\d{2}:\d{2})$', line)
        
        if speaker_match:
            # If we were building a previous message, save it
            if current_message:
                messages.append(current_message)
            
            # Start a new message
            current_message = {
                'speaker': speaker_match.group(1),
                'timestamp': speaker_match.group(2),
                'content': ""
            }
        elif current_message and line != '':
            # Add content line to current message
            current_message['content'] += line + "\n"
        elif current_message and line == '':
            # Empty line - could be end of message or just spacing
            # We'll keep building the current message until we hit a new speaker
            current_message['content'] += "\n"
    
    # Don't forget to add the last message if it exists
    if current_message:
        messages.append(current_message)
    
    return messages

def messages_to_string(messages):
    messages_str = ""
    for index, message in enumerate(messages):
        messages_str += f"{index}: [{message['speaker']}] {message['content']}"
    return messages_str

# Test the function with the Alex transcript
if 'Alex' in transcripts:
    parsed_messages = parseTranscript(transcripts['Alex'])
    messages_str = messages_to_string(parsed_messages)
    print(messages_str)
# Out:
# 0: [Alex Marasigan] Uh, hello?
#
# 1: [Chifang Chou] Hello, can you hear me? Okay, so, um, first of all, can you see my screen as well?
#
# 2: [Alex Marasigan] Yes.
#
# 3: [Alex Marasigan] Yes.
#
# 4: [Chifang Chou] Okay, so thank you so much for, um, signing up for the study, and later the process will be, like, um, I'll read you through the letter of information first, and then I will demo the study process for you, and then we will go straight to the study process.
#
# 5: [Chifang Chou] So, if you have any questions regarding the study, you can just interrupt me at any time, and I'll answer you directly.
#
# 6: [Alex Marasigan] Okay, thank you.
#
# 7: [Chifang Chou] Okay, so for the lot of information here, basically, our purpose here is that you'll later be asked to use an AI system.
#
# 8: [Chifang Chou] Which is ChatGPT here to explore a dataset and generate visualizations using natural language prompts.
#
# 9: [Chifang Chou] Describe your insights from the chart, reveal their clarity and usefulness, and complete a really short interview about your experience and the whole procedure should take about 1 hour, which is 60 minutes.
#
# 10: [Chifang Chou] Later, your screen will be recorded when using the tool, and the screen recordings are used only to verify test completion, interaction behavior with the AI system.
#
# 11: [Chifang Chou] The audio will be recorded during the interview session, and it will only be transcribed for analysis.
#
# 12: [Chifang Chou] for your name or any, like, personal information will not be included in the transcription.
#
# 13: [Chifang Chou] So, do you have any problems considering that letter of information?
#
# 14: [Alex Marasigan] Um, nope.
#
# 15: [Chifang Chou] Okay, then we'll go straight to the demo process, and I will show you what we need later. Let me share my screen one more time.
#
# 16: [Chifang Chou] Can you see my screen right now? Yes, okay, so have you used ChatGPT before?
#
# 17: [Alex Marasigan] Yes.
#
# 18: [Alex Marasigan] Um, yes, I have.
#
# 19: [Chifang Chou] Okay, awesome. So later, what we're going to do is, uh, this is ChatGPT's interface, and we are going to upload the dataset that I will provide you later. So, the first step for you is to log in to ChatGPT with the account that I will provide later. And after that, you can drag in the dataset, for example, like this. I'll drag in directly.
#
# 20: [Chifang Chou] Or you can use… also use the plus button here for uploading files, but it's up to you.
#
# 21: [Chifang Chou] And then we will go back to the scenario file. I'll also provide you the scenario file as well, and what scenario file is, is that, um, basically it provides the, um.
#
# 22: [Chifang Chou] Introduction, the dataset introduction, and three scenarios in your file. And for the introduction, it's a really short paragraph that just, um.
#
# 23: [Chifang Chou] Kindly tell you that what are the information inside the dataset, and you can also feel free to open the CSV file yourself to observe it. You can do whatever you like.
#
# 24: [Chifang Chou] And for the visualization scenario is the, um, top task here, is that you're going to read the paragraph here and put yourself in the scenario, and try to prompt ChatGPT to get the visualization in.
#
# 25: [Chifang Chou] Uh, to fulfill this kind of scenario. So, for example, here, imagine you are a regional sales analysis about to brief your team. Use the data center to show which regions are performing well and which might need improvement. How would you visualize the differences in total sales and profit to make your story convincing?
#
# 26: [Chifang Chou] So, for me, after I, um, read this scenario, after I put myself in the scenario, I'll start thinking, what's the important thing here to, um.
#
# 27: [Chifang Chou] For me to visualize, so probably I'll prompt like this, um, please generate.
#
# 28: [Chifang Chou] a visualization. Emphasizing… Um, total sales… And profits.
#
# 29: [Chifang Chou] In, uh, different… regions. Yeah, so based on what I read, probably I would think that this is a good prompt to, um, throw into ChatGPT.
#
# 30: [Chifang Chou] Then I would just send it out.
#
# 31: [Chifang Chou] And then wait for its generation.
#
# 32: [Chifang Chou] It might take a little while. Okay, so this is a chart that ChatGPT provided me. So, um, after that, after you, um, get the visualization and read maybe the context that ChatGPT provided you.
#
# 33: [Alex Marasigan] Mm-hmm.
#
# 34: [Chifang Chou] There are two ways that you can, um, go. First is that if you are not satisfied with the chart, you can keep prompting and keep asking ChatGPT to maybe improve the chart, to fix any problems you see from the chart.
#
# 35: [Chifang Chou] Uh, if you're already satisfied with, um. the visualization that ChatGPT gave you. I will also give you a survey link, and you can go through the survey link directly.
#
# 36: [Chifang Chou] And basically, the survey will look like this. Um, there's a page 1 that you need to, like, fill in your name, your email, and what dataset you use. This is page 2. So basically, after you get your IDO, which is.
#
# 37: [Chifang Chou] The dry season that satisfy you. You can go ahead to put down 3 to 5 inside subject gain from the visualization.
#
# 38: [Chifang Chou] So, the insights will be, like, um, the visualization you got, how can the visualization, um.
#
# 39: [Chifang Chou] Answer the scenarios question. So, a lot of things can be the.
#
# 40: [Chifang Chou] insights. So, for example, um, some participants from, um.
#
# 41: [Chifang Chou] Using other data sets, they might have insights like this, for example, like x-axis and y-axis are, um, positive correlated, something like that. That can all be the insights.
#
# 42: [Chifang Chou] And after the insights, you're going to fill in the, um… Scenario 1 survey, and after the survey, we'll have a really short interview about the answers you answer.
#
# 43: [Chifang Chou] And then we will go on to the next scenario. So we'll, um, basically do it 3 times, and after that, we'll click the button right here, and then go on to the very final part of the assessments, or your self-assessment survey.
#
# 44: [Chifang Chou] And then an interview again, and then that's the end of today's study.
#
# 45: [Chifang Chou] If there are any questions regarding the study?
#
# 46: [Alex Marasigan] Um, uh, not right now, no.
#
# 47: [Chifang Chou] Okay, so, um… good, and I'm going to go ahead on sending you information regarding the account and your.
#
# 48: [Chifang Chou] scenario files and the data set in the chat.
#
# 49: [Chifang Chou] So, um, if you're ready, you can start sharing your screen, and we can go, um, the process together, step by step.
#
# 50: [Alex Marasigan] Um, okay, I sent a request to share my screen.
#
# 51: [Chifang Chou] Okay, thank you, I saw that.
#
# 52: [Alex Marasigan] Um… okay.
#
# 53: [Alex Marasigan] Uh… and then I just go…
#
# 54: [Chifang Chou] Okay.
#
# 55: [Alex Marasigan] Here… oh, wait, no, I got a chat GPT.
#
# 56: [Chifang Chou] Yeah, and… If you are…
#
# 57: [Alex Marasigan] Oh, whoops.
#
# 58: [Chifang Chou] Let's see…
#
# 59: [Chifang Chou] Okay, looks good. And, uh, you have to log in through Google account.
#
# 60: [Alex Marasigan] Okay…
#
# 61: [Alex Marasigan] Okay.
#
# 62: [Chifang Chou] Okay, sounds good. So, we can go ahead, um, you can download the.
#
# 63: [Chifang Chou] dataset file from the chat as well, and open this, yeah, the scenario file.
#
# 64: [Alex Marasigan] Hmm…
#
# 65: [Alex Marasigan] Um…
#
# 66: [Alex Marasigan] Okay.
#
# 67: [Chifang Chou] So, if you see in the chat, there is a… dataset file. Is there anything wrong?
#
# 68: [Alex Marasigan] Oh, wait, um…
#
# 69: [Alex Marasigan] So… wait, is this the dataset?
#
# 70: [Chifang Chou] Oh, no, this is the scenario file that you'll need to read later, so the dataset file is still in the chat that you can take a look again.
#
# 71: [Alex Marasigan] Oh, okay, okay.
#
# 72: [Chifang Chou] It is a CSV file that you need to download.
#
# 73: [Chifang Chou] Yeah, exactly. Yeah, so, uh, by this, you can go back to the scenario file and start reading the, like, the introduction and the first scenario.
#
# 74: [Chifang Chou] And I'll leave you, like, 2 to 3 minutes, like, you can just, um, get the information from it, and whenever you're ready, we can start prompting.
#
# 75: [Alex Marasigan] Uh, this is only this task 1, right?
#
# 76: [Chifang Chou] Yeah, only task one. That's right.
#
# 77: [Alex Marasigan] Okay.
#
# 78: [Alex Marasigan] Hmm… am I allowed to open this?
#
# 79: [Chifang Chou] Open where?
#
# 80: [Alex Marasigan] Uh, to open this to see what, um…
#
# 81: [Alex Marasigan] like, what data is inside here.
#
# 82: [Chifang Chou] Of course, of course, you can do whatever you want to explore it, you can go ahead.
#
# 83: [Alex Marasigan] Okay, um…
#
# 84: [Alex Marasigan] I just wanted to see what…
#
# 85: [Alex Marasigan] is the data…
#
# 86: [Alex Marasigan] that I have to… okay.
#
# 87: [Chifang Chou] Mm-hmm, you can just, uh, explore whatever you want, just explore freely.
#
# 88: [Alex Marasigan] Hmm…
#
# 89: [Chifang Chou] And take your time, and just tell me whenever you're ready.
#
# 90: [Alex Marasigan] Uh, and then my task is to…
#
# 91: [Alex Marasigan] determine, uh…
#
# 92: [Alex Marasigan] how… or determine a prompt that would satisfy the…
#
# 93: [Alex Marasigan] there… this really… or, like,
#
# 94: [Alex Marasigan] is my job to figure out this relationship, or to generate something
#
# 95: [Alex Marasigan] That will figure out their relationship.
#
# 96: [Chifang Chou] Um… the latter one, so you need… you will need to, like, generate a visualization. So basically, a graph.
#
# 97: [Chifang Chou] To represent that scenario. Is that clear? Yeah.
#
# 98: [Alex Marasigan] Okay, okay.
#
# 99: [Alex Marasigan] Uh, am I only supposed to create one chart? Because it's asking for
#
# 100: [Alex Marasigan] two relationships?
#
# 101: [Chifang Chou] Um, yeah, only one, sorry.
#
# 102: [Alex Marasigan] Hmm… oh.
#
# 103: [Alex Marasigan] Um, okay.
#
# 104: [Chifang Chou] Mm-hmm.
#
# 105: [Alex Marasigan] Horsepower, miles per gallon…
#
# 106: [Alex Marasigan] And then…
#
# 107: [Chifang Chou] Mm-hmm.
#
# 108: [Alex Marasigan] Sorry, give me a sec.
#
# 109: [Chifang Chou] Is there a problem for you that you want to ask?
#
# 110: [Alex Marasigan] I'm trying to understand it, Bob.
#
# 111: [Alex Marasigan] I just asked them this.
#
# 112: [Chifang Chou] It's okay. You can just do whatever you want to prompt to ChatGPT, so… Don't be nervous about that.
#
# 113: [Alex Marasigan] Alright, um…
#
# 114: [Chifang Chou] And just a reminder that your ultimate goal is to get a visualization.
#
# 115: [Alex Marasigan] Um, oh yeah, okay, okay.
#
# 116: [Alex Marasigan] First responders.
#
# 117: [Alex Marasigan] Hmm… car weight?
#
# 118: [Alex Marasigan] Okay, I mean, I think this is good.
#
# 119: [Chifang Chou] Okay, so if you're, like, um, already satisfied with your chart, I can provide you the survey link right now.
#
# 120: [Chifang Chou] I'll paste it in the chat.
#
# 121: [Alex Marasigan] Okay.
#
# 122: [Chifang Chou] Okay, so you can fill in this first.
#
# 123: [Alex Marasigan] Um, what exactly am I supposed to describe here?
#
# 124: [Chifang Chou] Um, so basically, um, can I take a look at your chart again?
#
# 125: [Chifang Chou] Okay, so, um, there are a lot of things that you can describe about this chart that.
#
# 126: [Chifang Chou] Okay, so personally, for me, I would probably say that in this chart, I can see that miles per gallon and horsepower are somehow, like, negative correlated.
#
# 127: [Chifang Chou] But you don't need to do, like, what, exactly what I do, just.
#
# 128: [Chifang Chou] You can write now whatever you want that you observe from this chart. And, for example, there is different color of car weight.
#
# 129: [Chifang Chou] on different crosses, right? This can also be your insights, like, um, like, have your car weight will lead to, like, um, some better.
#
# 130: [Alex Marasigan] Mm-hmm.
#
# 131: [Chifang Chou] horsepower, or, um, higher miles per gallon, something like that, that's… those can all be your insights, so… Yeah, just feel free to… discovered it yourself, and you can all write it down.
#
# 132: [Alex Marasigan] Okay.
#
# 133: [Alex Marasigan] I have no idea how to describe this.
#
# 134: [Alex Marasigan] Um…
#
# 135: [Chifang Chou] It's going away.
#
# 136: [Alex Marasigan] Like…
#
# 137: [Alex Marasigan] Um, well, I obviously noticed that
#
# 138: [Alex Marasigan] The lighter it is,
#
# 139: [Chifang Chou] Mm-hmm.
#
# 140: [Alex Marasigan] Um, the ratio, uh, kind of…
#
# 141: [Alex Marasigan] I guess it… it… it becomes more one-to-uh, one-to-one. Uh, maybe I'll just say that.
#
# 142: [Chifang Chou] Yeah, don't worry about the phrasing or something, just… I think that it represents what you want to mean, then it's okay.
#
# 143: [Alex Marasigan] Um, okay.
#
# 144: [Alex Marasigan] Um, okay.
#
# 145: [Chifang Chou] Okay, so, um, we have finished… The first scenario, right? Can you, um.
#
# 146: [Chifang Chou] go back to the survey… For a little while, I will contact a really short interview. Okay, so, uh, for the insights, can you tell me that, um, how did you get those insights?
#
# 147: [Alex Marasigan] Mm-hmm.
#
# 148: [Alex Marasigan] Um…
#
# 149: [Alex Marasigan] like, describe how… what I see on the chart.
#
# 150: [Chifang Chou] Mm-hmm.
#
# 151: [Alex Marasigan] Okay.
#
# 152: [Chifang Chou] Oh, I just… I'm sorry, I just… Once you do, like, talked about the insights that you just listed, just, you can just talk about.
#
# 153: [Alex Marasigan] wrote to you. Okay.
#
# 154: [Chifang Chou] The insights that you got, yeah. I'm sorry, I'm sorry.
#
# 155: [Alex Marasigan] Um, so…
#
# 156: [Alex Marasigan] Well, like you mentioned in your example, um, I can see that it is going down, so it is
#
# 157: [Alex Marasigan] negative cor… uh, negatively correlated.
#
# 158: [Chifang Chou] Mm-hmm.
#
# 159: [Alex Marasigan] Um…
#
# 160: [Alex Marasigan] Yeah, and then…
#
# 161: [Alex Marasigan] Uh, as for how the car weight…
#
# 162: [Alex Marasigan] Um, like, uh…
#
# 163: [Alex Marasigan] influences the balance. Um, they're… the heavier, uh, based on this, uh, color,
#
# 164: [Alex Marasigan] The heavier the car weight is,
#
# 165: [Alex Marasigan] Uh, the more towards, uh, this side of the chart, it, uh, and then…
#
# 166: [Alex Marasigan] the lighter it is, the more over here.
#
# 167: [Alex Marasigan] Like, it is. So…
#
# 168: [Alex Marasigan] Um, if it's…
#
# 169: [Alex Marasigan] So, that basically means that the more
#
# 170: [Alex Marasigan] Um, the more heavier it is,
#
# 171: [Alex Marasigan] the less miles per gallon
#
# 172: [Alex Marasigan] Uh, or the more horsepower there is per mat.
#
# 173: [Alex Marasigan] per miles per gallon. Uh, and over here, it's more of, like, a one-to-one ratio, so, like, 50 is here, and 50 is, like, almost… so it's…
#
# 174: [Chifang Chou] Mm-hmm.
#
# 175: [Alex Marasigan] almost, like, one-to-one, kind of.
#
# 176: [Alex Marasigan] Um, yeah.
#
# 177: [Chifang Chou] Okay, I see. Okay, then let's go back to the survey.
#
# 178: [Chifang Chou] And then we, um, take a look at your answers. Can you scroll down a little bit? Okay.
#
# 179: [Chifang Chou] Um, so for the question that I do not, uh, feel the need to verify or double-check the AI-generated chart, you answer 1.
#
# 180: [Chifang Chou] Which is that you feel like you. Uh, super need to verify and double check, right?
#
# 181: [Chifang Chou] Can you tell me the reason for that and like.
#
# 182: [Chifang Chou] Um, what made you feel that way?
#
# 183: [Alex Marasigan] I mean, I… I always think it's…
#
# 184: [Alex Marasigan] Even if, uh, this was, like, I made this.
#
# 185: [Alex Marasigan] I feel like I… like, it's always good practice to, like, double check.
#
# 186: [Alex Marasigan] Um, I feel like even more so for AI,
#
# 187: [Alex Marasigan] Because, um, I mean, it doesn't…
#
# 188: [Alex Marasigan] Uh, sometimes it doesn't, um, uh, get the accurate results.
#
# 189: [Alex Marasigan] And that's, uh, just based off of my past experiences.
#
# 190: [Alex Marasigan] Um, with AI, um, in, uh, other stuff, so…
#
# 191: [Alex Marasigan] like, um, I guess…
#
# 192: [Alex Marasigan] uh, coding and, like, physics.
#
# 193: [Alex Marasigan] Um, hasn't always given me, like, the right…
#
# 194: [Alex Marasigan] answer. Um, so…
#
# 195: [Chifang Chou] Mm-hmm.
#
# 196: [Alex Marasigan] I think it's just good practice to just check if
#
# 197: [Alex Marasigan] Um, if the chart actually, um…
#
# 198: [Alex Marasigan] like, displays… not because of, like,
#
# 199: [Alex Marasigan] not because of anything, uh…
#
# 200: [Alex Marasigan] like, in this prompt, or in this response that is, like,
#
# 201: [Alex Marasigan] suspicious, but like…
#
# 202: [Alex Marasigan] Um, it's just… it'd just be good to double check.
#
# 203: [Chifang Chou] Okay, I see, and… Yeah, I guess it's… Okay, one more question that I'm confident in my own interpretation of the chart, answer 2 only.
#
# 204: [Chifang Chou] Um, yeah, can you also share the reason for that?
#
# 205: [Alex Marasigan] Um… well…
#
# 206: [Alex Marasigan] I'm gonna be honest, I, uh, I only, like, skim the data.
#
# 207: [Chifang Chou] Mm-hmm.
#
# 208: [Alex Marasigan] Um, I didn't…
#
# 209: [Alex Marasigan] uh… I mean…
#
# 210: [Alex Marasigan] I… I didn't collect this data.
#
# 211: [Alex Marasigan] Um, it was… it was just…
#
# 212: [Alex Marasigan] given to me.
#
# 213: [Alex Marasigan] Um, and also, I'm not very…
#
# 214: [Alex Marasigan] I'm not particularly confident.
#
# 215: [Chifang Chou] Mm-hmm.
#
# 216: [Alex Marasigan] Um, in…
#
# 217: [Alex Marasigan] Like, um…
#
# 218: [Alex Marasigan] I don't know, like, statistics and stuff.
#
# 219: [Alex Marasigan] So… oh.
#
# 220: [Chifang Chou] Oh, I see.
#
# 221: [Alex Marasigan] For me, personally, like,
#
# 222: [Alex Marasigan] I think it'd be nice to, like,
#
# 223: [Alex Marasigan] Um…
#
# 224: [Alex Marasigan] I… I don't know, I just don't really, um… I'm not really strong in statistics.
#
# 225: [Alex Marasigan] Um, so, yeah.
#
# 226: [Chifang Chou] Okay, I see. Okay, then I guess we can move on to the second scenario.
#
# 227: [Chifang Chou] And for the second scenario, please open a new chat, uh, traffic ChatGPT for me.
#
# 228: [Chifang Chou] And also the same process, just new chat and.
#
# 229: [Chifang Chou] Um, upload the data set again.
#
# 230: [Alex Marasigan] Um, the new data?
#
# 231: [Chifang Chou] Oh, no, the same one. The scenarios are based on the same data set for all these 3.
#
# 232: [Alex Marasigan] Oh, okay.
#
# 233: [Alex Marasigan] Okay.
#
# 234: [Alex Marasigan] Um…
#
# 235: [Alex Marasigan] I'm not quite sure how to determine fuel deficiency. Or, I mean, uh, inefficiency.
#
# 236: [Alex Marasigan] Should I ask, uh, the…
#
# 237: [Alex Marasigan] AI, or can I Google it?
#
# 238: [Chifang Chou] Um…
#
# 239: [Alex Marasigan] Or should I just include it in the prompt?
#
# 240: [Chifang Chou] Um, so…
#
# 241: [Chifang Chou] Let me… wait, let me… let me check for a little while.
#
# 242: [Chifang Chou] Okay, so basically, um… Because, um, the scenarios are made from the data set itself, so I believe that you can.
#
# 243: [Chifang Chou] Um, prompted directly to get that, but, um. Uh… yeah, because, uh… As, uh, in the scenario, fuel efficiency is actually can be calculated in the.
#
# 244: [Chifang Chou] table of the dataset, so. Yeah, I think you can just prompt directly by your intuition.
#
# 245: [Chifang Chou] Mm-hmm.
#
# 246: [Chifang Chou] And just a reminder, again, that what you need is a visualization, so… It's okay, you can freeze the next thing, yeah.
#
# 247: [Alex Marasigan] Oops.
#
# 248: [Chifang Chou] Okay, we can keep going and just tell me whenever you're ready.
#
# 249: [Alex Marasigan] Okay.
#
# 250: [Alex Marasigan] Wait, what?
#
# 251: [Chifang Chou] It's okay, take your time.
#
# 252: [Alex Marasigan] Okay, um…
#
# 253: [Alex Marasigan] Uh… I don't… I can type.
#
# 254: [Alex Marasigan] Oh, okay.
#
# 255: [Chifang Chou] Okay.
#
# 256: [Alex Marasigan] Wait, um…
#
# 257: [Chifang Chou] Yeah.
#
# 258: [Alex Marasigan] Different model years?
#
# 259: [Alex Marasigan] Wait, what does that mean?
#
# 260: [Chifang Chou] Different model years? Let me check the dataset.
#
# 261: [Chifang Chou] In different model years means there is a column of year, right? You can see that, right?
#
# 262: [Alex Marasigan] Um, yeah. Is it just…
#
# 263: [Chifang Chou] Uh, model years, uh, actually represented to the year here, and the region.
#
# 264: [Chifang Chou] Means the origin here. As you can see in the table.
#
# 265: [Chifang Chou] Or you can say that that's closely related to.
#
# 266: [Chifang Chou] The scenario that we want, right?
#
# 267: [Alex Marasigan] So, it has nothing to do with the actual model.
#
# 268: [Chifang Chou] Um… Actually, it depends on what you think, but you can say that as well.
#
# 269: [Chifang Chou] But that's why, like. We're doing this kind of user study because we want to know how you guys will, like, interpret.
#
# 270: [Chifang Chou] the scenario and the data as well, so. Mm-hmm, just… Yeah, just feel free to, like, generate what you think.
#
# 271: [Alex Marasigan] Okay, so it's my interpretation.
#
# 272: [Alex Marasigan] Okay, um…
#
# 273: [Alex Marasigan] Well
#
# 274: [Alex Marasigan] different model years.
#
# 275: [Chifang Chou] Mm-hmm.
#
# 276: [Alex Marasigan] I used my interpretation is that it'll show a relationship
#
# 277: [Alex Marasigan] Over time, of how…
#
# 278: [Alex Marasigan] Um, not just…
#
# 279: [Alex Marasigan] Wait a minute, miles per gallon?
#
# 280: [Chifang Chou] Mm-hmm. Right?
#
# 281: [Alex Marasigan] Oh, oh, wait, that makes sense. Okay.
#
# 282: [Alex Marasigan] Oh, okay. It showed this…
#
# 283: [Chifang Chou] Mm-hmm.
#
# 284: [Alex Marasigan] And also, um…
#
# 285: [Alex Marasigan] like, how…
#
# 286: [Alex Marasigan] like, different models, so, like…
#
# 287: [Alex Marasigan] I don't know what the VW is, but Volks… Volkswagen…
#
# 288: [Chifang Chou] Mm-hmm.
#
# 289: [Alex Marasigan] in, like, a Toyota.
#
# 290: [Alex Marasigan] it'll show another line like that.
#
# 291: [Chifang Chou] Mm-hmm, so…
#
# 292: [Chifang Chou] So your problem right now is that you don't know how to prime like this, or?
#
# 293: [Alex Marasigan] Is that what?
#
# 294: [Chifang Chou] So, what's your, like, the problem that you're facing right now, like…
#
# 295: [Alex Marasigan] Um…
#
# 296: [Alex Marasigan] it… I guess it interpreted it, like,
#
# 297: [Alex Marasigan] Um, it didn't lump together, um, all the Volkswagen together, because they're different models.
#
# 298: [Chifang Chou] Mm-hmm. Oh, okay. Then you can just, like, directly… say that what you think is wrong, or, like, what things you improve to ChatGPTs?
#
# 299: [Alex Marasigan] Excellent.
#
# 300: [Alex Marasigan] Okay.
#
# 301: [Chifang Chou] Yeah, just… if you… if it's your own work, that when you're doing homework, like, you face this kind of problems, what would you prompt? Just… Think like this. Don't be so stressed about, like, the user study.
#
# 302: [Alex Marasigan] Mm-hmm. Um…
#
# 303: [Alex Marasigan] Okay.
#
# 304: [Alex Marasigan] That's a lot of data.
#
# 305: [Chifang Chou] Okay, so if you're satisfied with it, we can go.
#
# 306: [Chifang Chou] Uh, onto the survey. If you're not, you can keep prompting, it's up to you.
#
# 307: [Alex Marasigan] Oops. There's a lot of lines, um…
#
# 308: [Alex Marasigan] Maybe, like…
#
# 309: [Alex Marasigan] There's one that's called High.
#
# 310: [Alex Marasigan] Let's see…
#
# 311: [Alex Marasigan] origin?
#
# 312: [Alex Marasigan] Oh, okay.
#
# 313: [Alex Marasigan] Okay, I'm gonna… I'm gonna try again.
#
# 314: [Chifang Chou] Okay, take your time.
#
# 315: [Alex Marasigan] Wait, what?
#
# 316: [Alex Marasigan] Um…
#
# 317: [Chifang Chou] That's so interesting that I want to go back to my own scenario file to take a look.
#
# 318: [Alex Marasigan] It's, um… yeah, it's, um…
#
# 319: [Alex Marasigan] Something, eh…
#
# 320: [Alex Marasigan] Let's see…
#
# 321: [Alex Marasigan] What happens if I'm not satisfied? What if I use the rest of the time to keep on prompting this?
#
# 322: [Chifang Chou] Oh. Okay, so, um… I guess… You still need to, like, pick one.
#
# 323: [Chifang Chou] Grab that if you feel like the most satisfied with, to fit the scenario, maybe.
#
# 324: [Chifang Chou] You can go back to the scenario again and to check that if what things are they actually emphasizing on.
#
# 325: [Chifang Chou] Instead, I guess.
#
# 326: [Alex Marasigan] Okay, um…
#
# 327: [Chifang Chou] Yeah, and there's a survey that will ask you that how clear and how can you interpret, right? You can, um… reflected on the survey as well, so don't worry.
#
# 328: [Alex Marasigan] Okay.
#
# 329: [Alex Marasigan] Um…
#
# 330: [Alex Marasigan] And this one is not the best.
#
# 331: [Alex Marasigan] But… it goes off the thumb.
#
# 332: [Alex Marasigan] But I think I… I… I might be able to understand it.
#
# 333: [Alex Marasigan] best.
#
# 334: [Alex Marasigan] Thank you.
#
# 335: [Chifang Chou] go with it to the survey.
#
# 336: [Alex Marasigan] Uh, and then I just described the relationship.
#
# 337: [Chifang Chou] Yeah, the insights that you want.
#
# 338: [Alex Marasigan] Okay, um…
#
# 339: [Alex Marasigan] Alright, zoom this in.
#
# 340: [Alex Marasigan] Oh, okay, bit too much.
#
# 341: [Alex Marasigan] Okay, um, I'm noticing…
#
# 342: [Alex Marasigan] Well, the general trend seems to be up.
#
# 343: [Chifang Chou] Mm-hmm, yeah, that's a really good insight that you can, uh, type down.
#
# 344: [Alex Marasigan] Yes. And then, as for the…
#
# 345: [Alex Marasigan] Origins?
#
# 346: [Alex Marasigan] It looks like…
#
# 347: [Alex Marasigan] brand that…
#
# 348: [Alex Marasigan] are part of…
#
# 349: [Alex Marasigan] Brands that are part of the U.S.?
#
# 350: [Alex Marasigan] It looks like, even though there's a lot, it tends to be…
#
# 351: [Alex Marasigan] On the lower… well, this is an 80.
#
# 352: [Alex Marasigan] too, but, um…
#
# 353: [Alex Marasigan] they tend to be, um…
#
# 354: [Chifang Chou] Mm-hmm. Mm-hmm.
#
# 355: [Alex Marasigan] less efficient?
#
# 356: [Alex Marasigan] And generally…
#
# 357: [Alex Marasigan] Japan, and then generally, except for… like, generally, very generally.
#
# 358: [Chifang Chou] Mm-hmm, mm-hmm. Yeah. Yeah.
#
# 359: [Alex Marasigan] Well, actually, Japan kind of looks like it's on top as well.
#
# 360: [Chifang Chou] You sound so prejudger. For… for discovering the inside. Sorry, that all sounds good.
#
# 361: [Alex Marasigan] Okay, um…
#
# 362: [Chifang Chou] Yeah, just take it down, no worries.
#
# 363: [Alex Marasigan] Okay, um…
#
# 364: [Alex Marasigan] Yeah, oh yeah.
#
# 365: [Alex Marasigan] And, um…
#
# 366: [Chifang Chou] Yeah. Just take your time.
#
# 367: [Alex Marasigan] Um, okay.
#
# 368: [Chifang Chou] So, um, we have done this survey, then, uh, the same thing is that I'm going to ask you some questions regarding your answer. So, the first one for the first question, can you tell me that what made it easy or difficult for you to understand? Because you select.
#
# 369: [Chifang Chou] 2, which is slightly for the very first question.
#
# 370: [Alex Marasigan] Um, so…
#
# 371: [Alex Marasigan] I mean, it… there's, um…
#
# 372: [Alex Marasigan] it's… well, first of all, the brand kind of goes off over here.
#
# 373: [Alex Marasigan] And it's… all the lines are just kinda…
#
# 374: [Alex Marasigan] like, everywhere. Like…
#
# 375: [Alex Marasigan] there is… it's kind of hard to pick apart the data.
#
# 376: [Alex Marasigan] Um… I really don't like how this is over here, um…
#
# 377: [Alex Marasigan] But… yeah.
#
# 378: [Chifang Chou] Mm-hmm.
#
# 379: [Alex Marasigan] And…
#
# 380: [Alex Marasigan] Um, yes.
#
# 381: [Chifang Chou] Okay, so, um, for the next question… Let me check.
#
# 382: [Chifang Chou] The last one, overall, I'm satisfied with the visualization generated by the AI for this dataset. You select 1, which is not of… Not at all. I know that you have already said that you're not satisfied with it, but can you just describe it one more time?
#
# 383: [Alex Marasigan] Um, yeah, I'm not really satisfied with how it visualized the data.
#
# 384: [Alex Marasigan] I mean, the key for all of the brands
#
# 385: [Alex Marasigan] like, it covers the data, and it also got… it's like…
#
# 386: [Alex Marasigan] way out of the, like,
#
# 387: [Chifang Chou] Yeah.
#
# 388: [Alex Marasigan] it's protruding out of the graph.
#
# 389: [Alex Marasigan] Um… it's kind of hard to understand
#
# 390: [Alex Marasigan] It, uh, the relationship.
#
# 391: [Alex Marasigan] Uh, between…
#
# 392: [Alex Marasigan] Uh, well, uh, the car brands are like, okay, but…
#
# 393: [Alex Marasigan] The origins… oh, I… I was hoping to get, like, an overview
#
# 394: [Alex Marasigan] Uh, kind of like the… the first…
#
# 395: [Alex Marasigan] graph of, like, how it, um, how it…
#
# 396: [Alex Marasigan] compares between different regions, and I didn't get that.
#
# 397: [Alex Marasigan] Uh, and I also did not get that even when I prompted, uh, again.
#
# 398: [Alex Marasigan] Um… uh…
#
# 399: [Alex Marasigan] And this is supposed to be…
#
# 400: [Alex Marasigan] This is supposed to be, um…
#
# 401: [Alex Marasigan] for a magazine.
#
# 402: [Alex Marasigan] Uh, so, I don't think…
#
# 403: [Alex Marasigan] people would be…
#
# 404: [Alex Marasigan] I also was hoping to just get, like, a
#
# 405: [Alex Marasigan] I didn't expect there to be, like, this much data.
#
# 406: [Alex Marasigan] So, uh…
#
# 407: [Chifang Chou] Mm-hmm.
#
# 408: [Alex Marasigan] I was kind of hoping to get, like, a visualization that would, like,
#
# 409: [Alex Marasigan] on, uh, kind of…
#
# 410: [Alex Marasigan] not have this much, so, uh, the readers aren't like…
#
# 411: [Alex Marasigan] Um, as…
#
# 412: [Alex Marasigan] like, confused and, like, overwhelmed by all this information that's here.
#
# 413: [Chifang Chou] Okay, I see. Um, then I guess that we can move forward to the very last scenario.
#
# 414: [Alex Marasigan] Okay.
#
# 415: [Chifang Chou] So, the same thing here, new chat, and upload the data set again.
#
# 416: [Chifang Chou] Um, you can get going.
#
# 417: [Alex Marasigan] Um…
#
# 418: [Alex Marasigan] You were calm.
#
# 419: [Alex Marasigan] Um, it's in… there's, like, 3 different charts. Uh, does that count?
#
# 420: [Chifang Chou] Um, uh… Um… it's a better choice for you to just give me one, like, visualization.
#
# 421: [Chifang Chou] So, you can probably fix the problem if you want.
#
# 422: [Alex Marasigan] Um, okay.
#
# 423: [Alex Marasigan] Mmm…
#
# 424: [Alex Marasigan] Alright, let's see what happens here.
#
# 425: [Alex Marasigan] Um, okay.
#
# 426: [Alex Marasigan] Uh, I'll just, like, finish this up, because I know…
#
# 427: [Alex Marasigan] And we only have, like, 2 minutes left.
#
# 428: [Chifang Chou] Are you in a hurry?
#
# 429: [Alex Marasigan] Uh, I have a thing to go to soon.
#
# 430: [Chifang Chou] Okay, then, yeah, just… Yeah.
#
# 431: [Alex Marasigan] Okay.
#
# 432: [Alex Marasigan] Uh… let's see…
#
# 433: [Alex Marasigan] Hmm
#
# 434: [Alex Marasigan] The mean?
#
# 435: [Alex Marasigan] Um, yeah.
#
# 436: [Chifang Chou] Okay, so, uh, just a quick interview as well, can you just talk really shortly about your insights first?
#
# 437: [Alex Marasigan] Uh, insights, so it's kind of hard to tell.
#
# 438: [Alex Marasigan] the difference between, um, miles per gallon and the acceleration for the three regions.
#
# 439: [Alex Marasigan] Um, but I think it's pretty obvious that…
#
# 440: [Alex Marasigan] horsepower, um, the US has a much wider range, and also, like,
#
# 441: [Chifang Chou] Mm-hmm.
#
# 442: [Alex Marasigan] generally, um, higher horsepower.
#
# 443: [Chifang Chou] Mm-hmm. Okay, sounds good.
#
# 444: [Alex Marasigan] Um, than the other two regions.
#
# 445: [Chifang Chou] And, um, for the questions that you just answered, uh, probably just.
#
# 446: [Chifang Chou] Focus on the third one. It's easy to read and interpret the chart's visual elements, axes, scales, copies, etc.
#
# 447: [Chifang Chou] You insert 2, which is slightly. Can you tell me the reason for that?
#
# 448: [Alex Marasigan] Well, I just feel like it's…
#
# 449: [Alex Marasigan] Um, it's kinda hard to compare.
#
# 450: [Alex Marasigan] uh, the miles per gallon and acceleration.
#
# 451: [Alex Marasigan] Because, uh, I guess, like,
#
# 452: [Alex Marasigan] Uh, it would be nice to have a zoomed-in version of that, because I low-key kind of feel the horsepower is, like,
#
# 453: [Alex Marasigan] Taking up too much space.
#
# 454: [Alex Marasigan] Um, so it's harder to see which value
#
# 455: [Alex Marasigan] is, like, better and bigger across the regions for…
#
# 456: [Alex Marasigan] miles per gallon and acceleration.
#
# 457: [Chifang Chou] Mmm, okay, I see. Then you can click the button, uh, the, yeah.
#
# 458: [Chifang Chou] And that's the final survey that we're going to do based on.
#
# 459: [Chifang Chou] Your, um, personal experience for today's study and after that we'll have a really short interview as well, so.
#
# 460: [Chifang Chou] Maybe 10 minutes late, I'm sorry for that.
#
# 461: [Alex Marasigan] Um, so I just finished this, and then…
#
# 462: [Chifang Chou] Yeah, just finished this and stay here, and I will ask you some questions based on your answers.
#
# 463: [Alex Marasigan] Okay, um…
#
# 464: [Alex Marasigan] Okay.
#
# 465: [Chifang Chou] Okay, so, um, based on your answers, can you, um, tell me that.
#
# 466: [Chifang Chou] Uh, for the first question, what helped or limited your sense of faithfulness?
#
# 467: [Alex Marasigan] Um, well, the first task went, uh, pretty well, but the second one…
#
# 468: [Alex Marasigan] Um, I didn't, uh, quite get to the point where it was, like,
#
# 469: [Alex Marasigan] Um, I, I got at the visualization that I wanted.
#
# 470: [Alex Marasigan] Um, and then for this one, I also, uh, couldn't, uh…
#
# 471: [Alex Marasigan] It's not really, uh, up to, uh, scale, so…
#
# 472: [Alex Marasigan] I…
#
# 473: [Alex Marasigan] I didn't really get… didn't…
#
# 474: [Alex Marasigan] really get the result that I wanted of the other two.
#
# 475: [Chifang Chou] Okay. Mm-hmm. And for the second question, was there anything about AI interface or responses that made it easier or harder for you to use?
#
# 476: [Alex Marasigan] Um… I feel like…
#
# 477: [Alex Marasigan] It's… hmm…
#
# 478: [Alex Marasigan] Less of the, like…
#
# 479: [Alex Marasigan] I don't know, I don't really understand… I… I feel like…
#
# 480: [Alex Marasigan] I think.
#
# 481: [Alex Marasigan] It was…
#
# 482: [Chifang Chou] Mm-hmm.
#
# 483: [Alex Marasigan] I… I feel like it's…
#
# 484: [Alex Marasigan] I think it's just because of my lack of experience with, like, data visualization that I don't…
#
# 485: [Alex Marasigan] I can't really… I don't really have the terms to communicate to the AI.
#
# 486: [Alex Marasigan] Um, how I want certain things to go through. So,
#
# 487: [Alex Marasigan] I feel like if I knew that, and I had a background,
#
# 488: [Alex Marasigan] in data visualization,
#
# 489: [Alex Marasigan] It would have been more easier and intuitive.
#
# 490: [Alex Marasigan] I'm sorry, I feel like it's less of, like, the AI and, like, modeling.
#
# 491: [Chifang Chou] Okay. That's okay, okay, I see. And for the next question, can you tell me how did you react or handle, like, the times that system gave you, like, inconsistent or confusing outputs?
#
# 492: [Alex Marasigan] Uh, sorry, could you repeat? Uh, could you repeat that?
#
# 493: [Chifang Chou] Um, so, how did you actually react or handle the situations that, when the system gave you some inconsistent or confusing outputs?
#
# 494: [Alex Marasigan] Um, I mean, I just tried again.
#
# 495: [Alex Marasigan] Uh, except for, uh, I couldn't really get… quite get to, like, the…
#
# 496: [Chifang Chou] Okay.
#
# 497: [Alex Marasigan] a… like, a product that, like,
#
# 498: [Alex Marasigan] Um, I'm satisfied with.
#
# 499: [Alex Marasigan] Because of time. Um, so…
#
# 500: [Chifang Chou] Mm-hmm.
#
# 501: [Alex Marasigan] Yeah, I think…
#
# 502: [Alex Marasigan] it just…
#
# 503: [Alex Marasigan] prompt, again, in, like,
#
# 504: [Alex Marasigan] Uh, especially, like, being more specific.
#
# 505: [Chifang Chou] Okay. Mm-hmm, I see. And, uh, how did you decide when to… for you to trust or to question the charge generated by the AI?
#
# 506: [Alex Marasigan] what I try to do.
#
# 507: [Alex Marasigan] The what?
#
# 508: [Chifang Chou] How did you decide when to trust or to question the charts generated by?
#
# 509: [Chifang Chou] AI.
#
# 510: [Alex Marasigan] Um, well…
#
# 511: [Alex Marasigan] If it's not understandable, I'm gonna question it.
#
# 512: [Alex Marasigan] Um, and also, um…
#
# 513: [Alex Marasigan] I mean, for the second one,
#
# 514: [Alex Marasigan] It was understandable, but I… it didn't really… it also…
#
# 515: [Alex Marasigan] uh, did not, like, fit my criteria of, like, what I imagined in my mind.
#
# 516: [Chifang Chou] Mmm, okay. Um, so, um, for the next question, um, can you tell me what would make you to trust the system more?
#
# 517: [Alex Marasigan] Um… I feel like it… it just…
#
# 518: [Alex Marasigan] Um, for me to trust it, I have to understand
#
# 519: [Alex Marasigan] Um, more about data visualization.
#
# 520: [Alex Marasigan] Uh, and also the data that I'm working with. This is the first time I'm, like, encountering this
#
# 521: [Alex Marasigan] like, data I didn't collect it.
#
# 522: [Chifang Chou] Mm-hmm. Okay. Ah.
#
# 523: [Alex Marasigan] Um… I didn't really…
#
# 524: [Alex Marasigan] Um, yeah, just…
#
# 525: [Chifang Chou] So, somehow you do not trust it because you… do not, like, collect the data for yourself, I'll say that, because you're not, like.
#
# 526: [Chifang Chou] You don't really understand the data?
#
# 527: [Alex Marasigan] Like, yeah, I…
#
# 528: [Alex Marasigan] I… I don't, um…
#
# 529: [Alex Marasigan] Yeah, I… I only… this is my first time working with this… these scenarios.
#
# 530: [Alex Marasigan] Maybe if I had, like, more…
#
# 531: [Chifang Chou] Mm-hmm.
#
# 532: [Alex Marasigan] time, or if I had spent more time, like,
#
# 533: [Alex Marasigan] um… understanding, uh, everything, I don't know. I…
#
# 534: [Alex Marasigan] I guess, like, it… all of this is kind of new to me. And I also don't really know much about cars.
#
# 535: [Chifang Chou] Okay, okay, I see. Okay, but it's okay, I mean, you did great, actually.
#
# 536: [Chifang Chou] And, uh, for the next question, can you tell me what would you change to make the system more satisfying or useful to you?
#
# 537: [Alex Marasigan] Um, satisfying?
#
# 538: [Alex Marasigan] Uh… I feel like…
#
# 539: [Alex Marasigan] I guess, like…
#
# 540: [Alex Marasigan] It's always satisfying to get it right the first try.
#
# 541: [Alex Marasigan] Um…
#
# 542: [Alex Marasigan] I guess… mmm…
#
# 543: [Alex Marasigan] Uh, I guess, like, bridging…
#
# 544: [Alex Marasigan] Like, or understanding.
#
# 545: [Alex Marasigan] Data visualization more, and like…
#
# 546: [Alex Marasigan] Maybe, like, understanding, like, the whole scenario,
#
# 547: [Alex Marasigan] just, like, everything more would make me feel more satisfied in…
#
# 548: [Alex Marasigan] what I have. Um…
#
# 549: [Alex Marasigan] I also…
#
# 550: [Chifang Chou] Mm-hmm.
#
# 551: [Alex Marasigan] Oh, wait, sorry, wait, give me a sec.
#
# 552: [Chifang Chou] Mm-hmm.
#
# 553: [Alex Marasigan] The other thing about this…
#
# 554: [Chifang Chou] Mm-hmm.
#
# 555: [Alex Marasigan] Yeah, I mean, I feel like…
#
# 556: [Alex Marasigan] There's also, like, some ethical concerns with AI.
#
# 557: [Alex Marasigan] Uh, regarding, like, the dataset, it, um, it has, and, like, also the environmental impact.
#
# 558: [Alex Marasigan] Um, so I think it…
#
# 559: [Alex Marasigan] it would be, like, more satisfying to use.
#
# 560: [Alex Marasigan] Um, like, some sort of AI that is, like,
#
# 561: [Alex Marasigan] Um, ethical.
#
# 562: [Chifang Chou] Okay, I see. And for the last two questions, is the question back to yourself after you use the tool?
#
# 563: [Chifang Chou] So, thinking back on the whole session, how confident do you feel about interpreting AI-generated visualizations right now?
#
# 564: [Alex Marasigan] like, from… compared to myself before?
#
# 565: [Chifang Chou] Yeah.
#
# 566: [Alex Marasigan] Um, not that much different. I didn't really, um, learn anything about data visualization, just how to
#
# 567: [Alex Marasigan] Um, work, or how to prompt it.
#
# 568: [Chifang Chou] Okay, so basically just gain an experienced. Okay, and for the last question, what stood out to you the most about the AI strengths or weaknesses in visualization?
#
# 569: [Alex Marasigan] Yeah.
#
# 570: [Chifang Chou] If you were to use a similar tool in your own breaker study, what would you hope to improve or keep the same?
#
# 571: [Alex Marasigan] Um, I mean, I was actually impressed that I was able to generate words, uh, because…
#
# 572: [Alex Marasigan] Uh, I don't know. I feel like… I thought last time I checked, like,
#
# 573: [Alex Marasigan] It couldn't, um… or its accuracy with words, um, was not that good.
#
# 574: [Chifang Chou] Mm-hmm. Um, if you were to use a similar tool in your own work or study, what would you hope to improve or keep the same?
#
# 575: [Alex Marasigan] And what was the second question?
#
# 576: [Alex Marasigan] Um…
#
# 577: [Alex Marasigan] When visualizing data,
#
# 578: [Alex Marasigan] Um… I'm not…
#
# 579: [Alex Marasigan] quite sure when…
#
# 580: [Alex Marasigan] I mean…
#
# 581: [Alex Marasigan] when would I use this again in my, uh, study?
#
# 582: [Chifang Chou] Mm-hmm.
#
# 583: [Alex Marasigan] Like, um, I'm not quite sure, like, because…
#
# 584: [Alex Marasigan] Yeah, I…
#
# 585: [Chifang Chou] And is there anything that you would like to improve or keep the same?
#
# 586: [Alex Marasigan] Um…
#
# 587: [Alex Marasigan] Probably…
#
# 588: [Alex Marasigan] I noticed that it generates…
#
# 589: [Alex Marasigan] Um, something that I can't really…
#
# 590: [Alex Marasigan] Wait, what is this? Oh.
#
# 591: [Alex Marasigan] Uh, maybe something where I can just go in and edit the chart itself.
#
# 592: [Alex Marasigan] Um, rather than having this where I can't really…
#
# 593: [Chifang Chou] Oh…
#
# 594: [Alex Marasigan] like, edit it myself. Oh, whoops.
#
# 595: [Alex Marasigan] I think that would, uh…
#
# 596: [Alex Marasigan] improved my experience.
#
# 597: [Chifang Chou] Okay, I see. Okay, then I guess it's the end of today's study, and just, uh, help me to click the button of the survey and send it out.
#
# 598: [Alex Marasigan] Oh, yes.
#
# 599: [Chifang Chou] Yeah, and that's the end of today's study, and the next step for you will be just signing out of this ChatGPT account, and for the compensation.
#
# 600: [Chifang Chou] That I mentioned, the $20 Amazon gift card, it will be sent to you through email around next week, because there is a, like, delay of the.
#
# 601: [Chifang Chou] you know, procedure of the process, because we have to get that mission of the department.
#
# 602: [Alex Marasigan] Mm-hmm.
#
# 603: [Chifang Chou] So, um, yeah, it's a little bit delayed, but I'll make sure to contact you through email later.
#
# 604: [Chifang Chou] And if you happen to have any questions regarding the study or the compensation, you can feel free to contact me through email too.
#
# 605: [Chifang Chou] And, uh, is there any questions that you want to ask right now?
#
# 606: [Alex Marasigan] Okay.
#
# 607: [Alex Marasigan] Um…
#
# 608: [Alex Marasigan] I, uh, I did psychology in, uh, high school.
#
# 609: [Alex Marasigan] Uh, and we had to, like, perform, like, a study. Are you, uh, in, in…
#
# 610: [Chifang Chou] Mm-hmm.
#
# 611: [Alex Marasigan] After we performed the study, we had to send out, like, participants and, like, what the results of the, like, study were. Are you, uh, also going to do the same thing?
#
# 612: [Chifang Chou] Um, basically, I haven't heard that before in the Department of Computer Science, but.
#
# 613: [Chifang Chou] Um, for the data, actually, we're using for more, um, research, and we are, of course, trying to, uh.
#
# 614: [Alex Marasigan] Yeah.
#
# 615: [Chifang Chou] Published a paper on that, so if you're curious, I can record it down and maybe I can.
#
# 616: [Chifang Chou] Send you when the paper is done, if you are curious.
#
# 617: [Alex Marasigan] Oh, okay. Okay.
#
# 618: [Chifang Chou] Yeah. Is there any more questions?
#
# 619: [Alex Marasigan] Um
#
# 620: [Alex Marasigan] Uh, could he actually just send me when the paper is published? Um, because I'd kind of be curious to see that.
#
# 621: [Chifang Chou] Yeah, of course. I will take it down and, um… I will make it as soon as possible, but I will take some time to, you know, produce the paper, you know.
#
# 622: [Alex Marasigan] Okay, yeah.
#
# 623: [Chifang Chou] Yeah, so, um, any more questions? Okay, then that's it for today's study. Thank you so much for participating again, and you can just, um, leave the meeting room directly, and thank you. Have a nice night.
#
# 624: [Alex Marasigan] Uh, nope.
#
# 625: [Alex Marasigan] Thank you!
#
# 626: [Chifang Chou] Bye, thank you.

# %%
prompt = [
    {
        "role": "system",
        "content": """You are a helpful assistant that segment transcripts.
        The user will give you a transcript with indices for each message, and the criteria for segmentation.
        You will follow the criteria to segment the transcript into sections, providing the start and end indices for each segment.
        Reply in the following JSON format:
        {
            "segments": [
                {
                    "start_index": <int>,
                    "end_index": <int>,
                    "title": "<str>"
                },
                ...
            ]
        }
        """
    },
    {
        "role": "user",
        "content": """
        This transcript is from a user study. The study is divided into an introduction session, three scenario/task sessions, each followed by a brief questionnaire, and then a final interview session. 
        Here is the transcript:
        {transcript}
        
        Please segment the transcript into sections based on the following criteria:
        - The first segment is the introduction, where one speaker introduces the topic and procedure.
        - The second segment is the first scenario/task session with its questionnaire.
        - The third segment is the second scenario/task session with its questionnaire.
        - The fourth segment is the third scenario/task session with its questionnaire.
        - The final segment is the interview session.
        Return the segments in the specified JSON format.
        """.format(transcript=messages_str)
    }
]

# %%
import os
import glob
from openai import OpenAI
# read txt files from transcripts/*.txt
transcript_files = glob.glob("transcripts/*.txt")
transcripts = {}

for file_path in transcript_files:
    # Extract filename without extension to use as key
    filename = os.path.splitext(os.path.basename(file_path))[0]
    
    # Read the content of each file
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()
        transcripts[filename] = content

print(f"Found {len(transcripts)} transcript files:")
for name in transcripts.keys():
    print(f"- {name}")
    
client = OpenAI()
responses = []
for name, content in transcripts.items():
    messages = parseTranscript(content)
    messages_to_str = messages_to_string(messages)
    segmentation_response = request_gpt(client, prompt, model="gpt-4o-mini", temperature=0, format="json")
    responses.append((name, messages, segmentation_response))
# Out:
# Found 1 transcript files:
# - Alex

# %%
segmentation_response = json.loads(responses[0][1])
segmentation_response
# Out:
# {'segments': [{'start_index': 0, 'end_index': 46, 'title': 'Introduction'},
#   {'start_index': 47,
#    'end_index': 145,
#    'title': 'First Scenario/Task Session'},
#   {'start_index': 226,
#    'end_index': 413,
#    'title': 'Second Scenario/Task Session'},
#   {'start_index': 414,
#    'end_index': 601,
#    'title': 'Third Scenario/Task Session'},
#   {'start_index': 602, 'end_index': 626, 'title': 'Final Interview Session'}]}

# %%
def parse_index(segment, messages):
    start_index = segment["start_index"]
    end_index = segment["end_index"]
    segment_messages = messages[start_index:end_index + 1]
    segment["messages"] = segment_messages
    return segment
for name, messages, segmentation_response_str in responses:
    segmentation_list = json.loads(segmentation_response_str)
    print(segmentation_list)
    for index, segment_response in enumerate(segmentation_list["segments"]):
        segmented_with_messages = parse_index(segment_response, messages)
        print(f"Transcript: {name}")
        with open(f"segmented/{name}_{index}.json", "w") as f:
            json.dump(segmented_with_messages, f, indent=4)
# Out:
# {'segments': [{'start_index': 0, 'end_index': 46, 'title': 'Introduction'}, {'start_index': 47, 'end_index': 145, 'title': 'First Scenario/Task Session'}, {'start_index': 226, 'end_index': 413, 'title': 'Second Scenario/Task Session'}, {'start_index': 414, 'end_index': 601, 'title': 'Third Scenario/Task Session'}, {'start_index': 602, 'end_index': 626, 'title': 'Final Interview Session'}]}
# Transcript: Alex
# Transcript: Alex
# Transcript: Alex
# Transcript: Alex
# Transcript: Alex
